# %% [markdown]
# <a href="https://colab.research.google.com/github/SAMYSOSERIOUS/Stats-analytics/blob/main/DataDay1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=[12,15,14,10,18,20,22,17,19,13,16,15,14,21,23]
mean_d=np.mean(data)
print("mean",mean_d)
median_d=np.median(data)
print("median",median_d)
std_d=np.std(data)
print("standard deviation",std_d)
variance_d=np.var(data)
print("variance",variance_d)
range_d=np.max(data)-np.min(data)
print("range",range_d)
minus_std=mean_d-std_d
plus_std=mean_d+std_d
print("mean -standard devaition=",minus_std)
print("mean -standard devaition=",plus_std)
plt.hist(bins=10,x=data)
plt.xlabel('data')
plt.ylabel('frequency')
plt.title('histogram')
plt.axvline(x=mean_d,color='red',linestyle='--',label='mean')
plt.legend()
plt.axvline(x=minus_std,color='green',linestyle='--',label='minus_std')
plt.legend()
plt.axvline(x=plus_std,color='green',linestyle='--',label='plus_std')
plt.legend()
plt.axvspan(minus_std, plus_std, alpha=0.2, color='yellow', label='±std')
plt.legend()
plt.show()
# Out:
# mean 16.6
# median 16.0
# standard deviation 3.702251567177286
# variance 13.706666666666669
# range 13
# mean -standard devaition= 12.897748432822716
# mean -standard devaition= 20.302251567177287

# %% [markdown]
# The histogram has a roughly symmetric distribution, meaning that the data is evenly spread around the center.
# there are outliers outside the one standard deviation range shown in yellow.

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
print(iris)
if iris.empty:
    print("iris.csv is empty")
else:
    print("iris.csv is not empty")
print(iris.head())
setosa_data = iris[iris.species == "setosa"]
mean_d=np.mean(setosa_data.sepal_length)
print("mean",mean_d)
median_d=np.median(setosa_data.sepal_length)
print("median",median_d)
std_d=np.std(setosa_data.sepal_length)
print("standard deviation",std_d)
variance_d=np.var(setosa_data.sepal_length)
print("variance",variance_d)
range_d=np.max(setosa_data.sepal_length)-np.min(setosa_data.sepal_length)
print("range",range_d)
max_d=np.max(setosa_data.sepal_length)
print("max",max_d)
min_d=np.min(setosa_data.sepal_length)
print("min",min_d)
minus_std=mean_d-std_d
plus_std=mean_d+std_d
print("mean -standard devaition=",minus_std)
print("mean -standard devaition=",plus_std)

verginica_data = iris[iris.species == "virginica"]
print(verginica_data)
mean_dver=np.mean(verginica_data.sepal_length)
print("mean",mean_dver)
median_dver=np.median(verginica_data.sepal_length)
print("median",median_dver)
std_dver=np.std(verginica_data.sepal_length)
print("standard deviation",std_dver)
variance_dver=np.var(verginica_data.sepal_length)
print("variance",variance_dver)
range_dver=np.max(verginica_data.sepal_length)-np.min(verginica_data.sepal_length)
print("range",range_dver)
max_dver=np.max(verginica_data.sepal_length)
print("max",max_dver)
min_dver=np.min(verginica_data.sepal_length)
print("min",min_dver)
minus_stdver=mean_dver-std_dver
plus_stdver=mean_dver+std_dver
print("mean -standard devaition=",minus_stdver)
print("mean -standard devaition=",plus_stdver)



plt.hist(bins=10,x=setosa_data.sepal_length,alpha=0.5,label='setosa',color="blue")
plt.hist(bins=10,x=verginica_data.sepal_length,alpha=0.7,label='verginica',color="red")
plt.axvline(x=max_d,color='blue',linestyle='-',label='range')
plt.axvline(x=min_d,color='blue',linestyle='-',label='range')

plt.axvline(x=mean_d,color='black',linestyle='--',label='mean')

plt.axvline(x=minus_std,color='green',linestyle='--',label='minus_std')
plt.axvline(x=plus_std,color='green',linestyle='--',label='plus_std')

plt.axvspan(minus_std, plus_std, alpha=0.2, color='yellow', label='±std')
plt.axvline(x=mean_dver,color='black',linestyle='--',label='mean')

plt.axvline(x=minus_stdver,color='green',linestyle='--',label='minus_std')
plt.axvline(x=plus_stdver,color='green',linestyle='--',label='plus_std')
plt.axvline(x=max_dver,color='red',linestyle='-',label='range')
plt.axvline(x=min_dver,color='red',linestyle='-',label='range')
plt.axvspan(minus_stdver, plus_stdver, alpha=0.2, color='yellow', label='±std')
plt.legend()
plt.xlabel('sepal_length')
plt.ylabel('frequency')
plt.title('Overlapping Histograms')
plt.legend()
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# iris.csv is not empty
#    sepal_length  sepal_width  petal_length  petal_width species
# ...

# %% [markdown]
# Mean: The mean sepal length for setosa is around 5.0 cm, while for virginica it is around 6.5 cm. This suggests that virginica flowers tend to have longer sepals on average.
#
# Standard Deviation: The standard deviation for setosa appears to be smaller than for virginica. This means that setosa flowers tend to have more consistent sepal lengths.
#
# Range: The range of sepal lengths for virginica is bigger than for setosa. This further supports the idea that setosa flowers have more consistent sepal lengths.
#
# sepal length is not a clear discriminator between setosa and virginica but it can be used to distinguishing the two flower species.
