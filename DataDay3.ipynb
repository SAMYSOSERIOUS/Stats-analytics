# %% [markdown]
# <a href="https://colab.research.google.com/github/SAMYSOSERIOUS/Stats-analytics/blob/main/DataDay3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# load Iris

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# sample Iris (30 observations)

# %%
sample = iris.sample(n=30)
sample
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 29            4.7          3.2           1.6          0.2      setosa
# 121           5.6          2.8           4.9          2.0   virginica
# 91            6.1          3.0           4.6          1.4  versicolor
# 127           6.1          3.0           4.9          1.8   virginica
# 106           4.9          2.5           4.5          1.7   virginica
# 53            5.5          2.3           4.0          1.3  versicolor
# 63            6.1          2.9           4.7          1.4  versicolor
# 98            5.1          2.5           3.0          1.1  versicolor
# 90            5.5          2.6           4.4          1.2  versicolor
# 8             4.4          2.9           1.4          0.2      setosa
# 71            6.1          2.8           4.0          1.3  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# ...

# %% [markdown]
# sample mean ditribution Analysis 100 times for the mean sepal length and plot as a histogram

# %%
import matplotlib.pyplot as plt

def radomize_n(n):
  means=[]
  for i in range(n):
    sample = iris.sample(n=30)
    mean=sample.sepal_length.mean()
    means.append(mean)
  return means

print("write number of samplings")
n=int(input())
meanslist=radomize_n(n)
print(meanslist)
plt.hist(meanslist)
plt.title("mean distribution")
plt.xlabel("mean")
plt.ylabel("frequency")
plt.show()
# Out:
# write number of samplings
# 20
# [5.660000000000001, 6.153333333333333, 5.923333333333334, 5.983333333333333, 5.973333333333334, 5.876666666666666, 5.706666666666666, 5.893333333333332, 5.920000000000001, 5.7, 5.936666666666666, 5.840000000000001, 5.920000000000001, 5.493333333333334, 5.833333333333332, 5.916666666666668, 5.736666666666666, 5.716666666666667, 5.716666666666668, 5.929999999999999]

# %% [markdown]
# systemic sampling by taking 20 percent of dataset then plot original dataset and sampled data

# %%
import matplotlib.pyplot as plt
import numpy as np
print("systemic sampling")
def systematic_sampling(df,step):
  indexes=np.arange(0,len(df),step=step)
  systemic_sample=df.iloc[indexes]
  return systemic_sample
print(len(iris))
print("write percentage :")
percentage=float(input())/100
systemic_sample=systematic_sampling(iris,1/percentage)
print(systemic_sample)
plt.hist(x=systemic_sample.sepal_length,color="red",alpha=0.7)
plt.hist(x=iris.sepal_length,color="blue",alpha=0.3)
plt.title("sepal length")
plt.xlabel("sepal length")
plt.ylabel("frequency")
plt.legend()
plt.show()
# Out:
# systemic sampling
# 150
# write percentage :
# 20
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
# 20            5.4          3.4           1.7          0.2      setosa
# 25            5.0          3.0           1.6          0.2      setosa
# 30            4.8          3.1           1.6          0.2      setosa
# 35            5.0          3.2           1.2          0.2      setosa
# 40            5.0          3.5           1.3          0.3      setosa
# ...
