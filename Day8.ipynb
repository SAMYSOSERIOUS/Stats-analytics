# %% [markdown]
# <a href="https://colab.research.google.com/github/SAMYSOSERIOUS/Stats-analytics/blob/main/Day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Decision Tree

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree
import matplotlib.pyplot as plt

iris = load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)

accuracyDT = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracyDT}")

plt.figure(figsize=(12,8))
tree.plot_tree(dtree,
                   feature_names=iris.feature_names,
                   class_names=iris.target_names,
                   filled=True, rounded=True)
plt.show()
# Out:
# Accuracy: 0.7333333333333333

# %% [markdown]
# # Random Forrest

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

iris = load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

rfc = RandomForestClassifier(n_estimators=10, random_state=1)
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

accuracyRF = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracyRF}")

feature_imp = pd.Series(rfc.feature_importances_, index=iris.feature_names).sort_values(ascending=False)
plt.figure(figsize=(10,6))
sns.barplot(x=feature_imp, y=feature_imp.index)
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()
# Out:
# Accuracy: 0.9555555555555556

# %% [markdown]
# # k-nearest neighbors algorithm

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
import numpy as np

iris = load_iris()
X = iris.data[:, :2]
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)


neighbors = range(1, 11)
accuracy_scores = []
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracyKNN = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracyKNN)
    print(f"Accuracy for  number of neighbors ={k} : {accuracyKNN}")

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                         np.arange(y_min, y_max, 0.02))

Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

plt.figure(figsize=(8, 6))
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("K-Nearest Neighbors Classification (k=5)")
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])

color_titles = {
    '#FF0000': iris.target_names[0],
    '#00FF00': iris.target_names[1],
    '#0000FF': iris.target_names[2],
}
for color, title in color_titles.items():
    plt.scatter([], [], c=color, label=title)
plt.legend()
plt.show()
plt.show()
# Out:
# Accuracy for  number of neighbors =1 : 0.6222222222222222
# Accuracy for  number of neighbors =2 : 0.6444444444444445
# Accuracy for  number of neighbors =3 : 0.6444444444444445
# Accuracy for  number of neighbors =4 : 0.6444444444444445
# Accuracy for  number of neighbors =5 : 0.7333333333333333
# Accuracy for  number of neighbors =6 : 0.7333333333333333
# Accuracy for  number of neighbors =7 : 0.7555555555555555
# Accuracy for  number of neighbors =8 : 0.7333333333333333
# Accuracy for  number of neighbors =9 : 0.7777777777777778
# Accuracy for  number of neighbors =10 : 0.7777777777777778

# %% [markdown]
# # **Convolutional neural network**

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

iris = load_iris()
X = iris.data
y = iris.target

y = keras.utils.to_categorical(y, num_classes=3)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)


X_train = X_train.reshape(X_train.shape[0], 4, 1, 1)
X_test = X_test.reshape(X_test.shape[0], 4, 1, 1)

model = keras.Sequential([
    keras.layers.Conv2D(32, kernel_size=(2, 1), activation='relu', input_shape=(4, 1, 1)),
    keras.layers.MaxPooling2D(pool_size=(2, 1)),
    keras.layers.Flatten(),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(3, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=50, batch_size=10, validation_data=(X_test,y_test))


loss, accuracyCNN = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracyCNN:.4f}")

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.3500 - loss: 1.5373 - val_accuracy: 0.3111 - val_loss: 1.5114
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3607 - loss: 1.3442 - val_accuracy: 0.2444 - val_loss: 1.3394
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1530 - loss: 1.2489 - val_accuracy: 0.0000e+00 - val_loss: 1.2307
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0511 - loss: 1.1308 - val_accuracy: 0.2889 - val_loss: 1.1683
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3543 - loss: 1.1004 - val_accuracy: 0.2889 - val_loss: 1.1276
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3836 - loss: 1.0772 - val_accuracy: 0.2889 - val_loss: 1.1081
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4037 - loss: 1.0673 - val_accuracy: 0.2889 - val_loss: 1.0884
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3671 - loss: 1.0597 - val_accuracy: 0.2889 - val_loss: 1.0760
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3308 - loss: 1.0617 - val_accuracy: 0.2889 - val_loss: 1.0624
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3242 - loss: 1.0415 - val_accuracy: 0.2889 - val_loss: 1.0478
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3337 - loss: 1.0264 - val_accuracy: 0.2889 - val_loss: 1.0356
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3199 - loss: 1.0115 - val_accuracy: 0.2889 - val_loss: 1.0218
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3094 - loss: 1.0110 - val_accuracy: 0.3333 - val_loss: 0.9921
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5622 - loss: 0.9656 - val_accuracy: 0.4889 - val_loss: 0.9780
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6455 - loss: 0.9233 - val_accuracy: 0.5778 - val_loss: 0.9608
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6813 - loss: 0.9123 - val_accuracy: 0.6000 - val_loss: 0.9338
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6877 - loss: 0.9040 - val_accuracy: 0.6000 - val_loss: 0.9075
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7148 - loss: 0.8666 - val_accuracy: 0.6000 - val_loss: 0.8885
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7024 - loss: 0.8441 - val_accuracy: 0.6000 - val_loss: 0.8603
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6459 - loss: 0.8462 - val_accuracy: 0.6000 - val_loss: 0.8277
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7511 - loss: 0.7778 - val_accuracy: 0.6000 - val_loss: 0.8100
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6941 - loss: 0.7693 - val_accuracy: 0.6000 - val_loss: 0.7787
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6729 - loss: 0.7493 - val_accuracy: 0.6000 - val_loss: 0.7456
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6966 - loss: 0.7266 - val_accuracy: 0.6000 - val_loss: 0.7258
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7110 - loss: 0.6694 - val_accuracy: 0.6000 - val_loss: 0.6948
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7165 - loss: 0.6408 - val_accuracy: 0.6000 - val_loss: 0.6707
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7357 - loss: 0.6331 - val_accuracy: 0.6000 - val_loss: 0.6487
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7106 - loss: 0.6124 - val_accuracy: 0.6222 - val_loss: 0.6191
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7476 - loss: 0.6128 - val_accuracy: 0.7333 - val_loss: 0.5948
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7647 - loss: 0.5537 - val_accuracy: 0.6222 - val_loss: 0.5871
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7068 - loss: 0.5477 - val_accuracy: 0.6222 - val_loss: 0.5727
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7258 - loss: 0.5112 - val_accuracy: 0.6222 - val_loss: 0.5500
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7671 - loss: 0.5008 - val_accuracy: 0.6667 - val_loss: 0.5341
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8085 - loss: 0.4912 - val_accuracy: 0.6222 - val_loss: 0.5242
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8728 - loss: 0.4716 - val_accuracy: 0.7333 - val_loss: 0.5069
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8774 - loss: 0.4460 - val_accuracy: 0.7333 - val_loss: 0.4955
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8267 - loss: 0.4612 - val_accuracy: 0.7333 - val_loss: 0.4817
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8831 - loss: 0.4273 - val_accuracy: 0.6222 - val_loss: 0.4872
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8311 - loss: 0.4611 - val_accuracy: 0.8444 - val_loss: 0.4577
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9174 - loss: 0.4228 - val_accuracy: 0.7333 - val_loss: 0.4579
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8650 - loss: 0.4537 - val_accuracy: 0.7556 - val_loss: 0.4483
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8800 - loss: 0.3884 - val_accuracy: 0.7333 - val_loss: 0.4547
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8674 - loss: 0.4460 - val_accuracy: 0.9333 - val_loss: 0.4213
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9269 - loss: 0.3814 - val_accuracy: 0.8000 - val_loss: 0.4249
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9334 - loss: 0.3699 - val_accuracy: 0.8000 - val_loss: 0.4221
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9038 - loss: 0.3803 - val_accuracy: 0.9111 - val_loss: 0.4066
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9543 - loss: 0.3777 - val_accuracy: 0.9111 - val_loss: 0.3994
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9067 - loss: 0.3552 - val_accuracy: 0.8000 - val_loss: 0.4083
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9215 - loss: 0.3590 - val_accuracy: 0.8889 - val_loss: 0.3919
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9241 - loss: 0.3409 - val_accuracy: 0.8000 - val_loss: 0.3999
# Test Loss: 0.3999
# Test Accuracy: 0.8000

# %%
# prompt: compare the acuracies of all previous models

import pandas as pd

# Create a dictionary to store the accuracy results
accuracy_results = {
    'Model': ['Decision Tree', 'Random Forest', 'k-NN', 'CNN'],
    'Accuracy': [accuracyDT, accuracyRF, accuracyKNN, accuracyCNN]
}

# Create a pandas DataFrame from the results
accuracy_df = pd.DataFrame(accuracy_results)

# Display the DataFrame
accuracy_df
# Out:
#            Model  Accuracy
# 0  Decision Tree  0.955556
# 1  Random Forest  0.955556
# 2           k-NN  0.777778
# 3            CNN  0.800000
