# %% [markdown]
# <a href="https://colab.research.google.com/github/SAMYSOSERIOUS/Stats-analytics/blob/main/DataDay8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Decision Tree

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree
import matplotlib.pyplot as plt

iris = load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)

accuracyDT = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracyDT}")

plt.figure(figsize=(12,8))
tree.plot_tree(dtree,
                   feature_names=iris.feature_names,
                   class_names=iris.target_names,
                   filled=True, rounded=True)
plt.show()
# Out:
# Accuracy: 0.9555555555555556

# %% [markdown]
# # Random Forrest

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

iris = load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

rfc = RandomForestClassifier(n_estimators=10, random_state=1)
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

accuracyRF = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracyRF}")

feature_imp = pd.Series(rfc.feature_importances_, index=iris.feature_names).sort_values(ascending=False)
plt.figure(figsize=(10,6))
sns.barplot(x=feature_imp, y=feature_imp.index)
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()
# Out:
# Accuracy: 0.9555555555555556

# %% [markdown]
# # k-nearest neighbors algorithm

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
import numpy as np

iris = load_iris()
X = iris.data[:, :2]
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)


neighbors = range(1, 11)
accuracy_scores = []
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracyKNN = accuracy_score(y_test, y_pred)
    accuracy_scores.append(accuracyKNN)
    print(f"Accuracy for  number of neighbors ={k} : {accuracyKNN}")

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                         np.arange(y_min, y_max, 0.02))

Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

plt.figure(figsize=(8, 6))
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("K-Nearest Neighbors Classification (k=5)")
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])

color_titles = {
    '#FF0000': iris.target_names[0],
    '#00FF00': iris.target_names[1],
    '#0000FF': iris.target_names[2],
}
for color, title in color_titles.items():
    plt.scatter([], [], c=color, label=title)
plt.legend()
plt.show()
plt.show()
# Out:
# Accuracy for  number of neighbors =1 : 0.6222222222222222
# Accuracy for  number of neighbors =2 : 0.6444444444444445
# Accuracy for  number of neighbors =3 : 0.6444444444444445
# Accuracy for  number of neighbors =4 : 0.6444444444444445
# Accuracy for  number of neighbors =5 : 0.7333333333333333
# Accuracy for  number of neighbors =6 : 0.7333333333333333
# Accuracy for  number of neighbors =7 : 0.7555555555555555
# Accuracy for  number of neighbors =8 : 0.7333333333333333
# Accuracy for  number of neighbors =9 : 0.7777777777777778
# Accuracy for  number of neighbors =10 : 0.7777777777777778

# %% [markdown]
# # **Convolutional neural network**

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

iris = load_iris()
X = iris.data
y = iris.target

y = keras.utils.to_categorical(y, num_classes=3)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)


X_train = X_train.reshape(X_train.shape[0], 4, 1, 1)
X_test = X_test.reshape(X_test.shape[0], 4, 1, 1)

model = keras.Sequential([
    keras.layers.Conv2D(32, kernel_size=(2, 1), activation='relu', input_shape=(4, 1, 1)),
    keras.layers.MaxPooling2D(pool_size=(2, 1)),
    keras.layers.Flatten(),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(3, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=50, batch_size=10, validation_data=(X_test,y_test))


loss, accuracyCNN = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracyCNN:.4f}")

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4026 - loss: 1.0920 - val_accuracy: 0.6000 - val_loss: 1.0787
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6465 - loss: 1.0584 - val_accuracy: 0.3556 - val_loss: 1.0515
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3084 - loss: 1.0411 - val_accuracy: 0.5111 - val_loss: 1.0284
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4154 - loss: 1.0119 - val_accuracy: 0.6000 - val_loss: 1.0105
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6258 - loss: 0.9790 - val_accuracy: 0.6000 - val_loss: 1.0006
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6554 - loss: 0.9812 - val_accuracy: 0.6000 - val_loss: 0.9773
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7094 - loss: 0.9478 - val_accuracy: 0.6000 - val_loss: 0.9590
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7223 - loss: 0.9191 - val_accuracy: 0.6000 - val_loss: 0.9405
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6779 - loss: 0.9232 - val_accuracy: 0.6000 - val_loss: 0.9170
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7034 - loss: 0.8829 - val_accuracy: 0.6000 - val_loss: 0.8948
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6433 - loss: 0.8854 - val_accuracy: 0.6000 - val_loss: 0.8668
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6473 - loss: 0.8528 - val_accuracy: 0.6000 - val_loss: 0.8504
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6976 - loss: 0.8178 - val_accuracy: 0.6000 - val_loss: 0.8315
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7059 - loss: 0.7858 - val_accuracy: 0.6000 - val_loss: 0.7984
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6767 - loss: 0.7628 - val_accuracy: 0.6222 - val_loss: 0.7644
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7213 - loss: 0.7257 - val_accuracy: 0.6000 - val_loss: 0.7487
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6692 - loss: 0.7193 - val_accuracy: 0.6000 - val_loss: 0.7224
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6711 - loss: 0.6918 - val_accuracy: 0.6000 - val_loss: 0.6959
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7476 - loss: 0.6284 - val_accuracy: 0.6000 - val_loss: 0.6793
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6678 - loss: 0.6473 - val_accuracy: 0.6222 - val_loss: 0.6447
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7679 - loss: 0.5745 - val_accuracy: 0.6222 - val_loss: 0.6320
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6904 - loss: 0.5807 - val_accuracy: 0.6222 - val_loss: 0.6096
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7079 - loss: 0.5751 - val_accuracy: 0.6222 - val_loss: 0.5951
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7099 - loss: 0.5609 - val_accuracy: 0.6222 - val_loss: 0.5759
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7667 - loss: 0.5211 - val_accuracy: 0.6222 - val_loss: 0.5567
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7837 - loss: 0.4935 - val_accuracy: 0.6889 - val_loss: 0.5395
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7978 - loss: 0.4899 - val_accuracy: 0.6222 - val_loss: 0.5350
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7787 - loss: 0.4962 - val_accuracy: 0.6889 - val_loss: 0.5167
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8500 - loss: 0.4723 - val_accuracy: 0.7333 - val_loss: 0.5040
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8724 - loss: 0.4505 - val_accuracy: 0.7333 - val_loss: 0.4948
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8111 - loss: 0.4784 - val_accuracy: 0.7333 - val_loss: 0.4861
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8149 - loss: 0.4394 - val_accuracy: 0.6444 - val_loss: 0.4834
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8693 - loss: 0.3975 - val_accuracy: 0.7333 - val_loss: 0.4680
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8926 - loss: 0.4375 - val_accuracy: 0.7333 - val_loss: 0.4636
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8977 - loss: 0.4057 - val_accuracy: 0.6444 - val_loss: 0.4644
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8318 - loss: 0.4044 - val_accuracy: 0.8667 - val_loss: 0.4409
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9200 - loss: 0.3597 - val_accuracy: 0.7333 - val_loss: 0.4490
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8167 - loss: 0.4464 - val_accuracy: 0.9556 - val_loss: 0.4179
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9189 - loss: 0.4069 - val_accuracy: 0.7333 - val_loss: 0.4386
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9259 - loss: 0.3708 - val_accuracy: 0.8000 - val_loss: 0.4198
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9079 - loss: 0.3907 - val_accuracy: 0.8889 - val_loss: 0.4089
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9381 - loss: 0.3871 - val_accuracy: 0.9111 - val_loss: 0.3964
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9287 - loss: 0.3565 - val_accuracy: 0.8222 - val_loss: 0.4015
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9185 - loss: 0.3763 - val_accuracy: 0.9333 - val_loss: 0.3840
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9158 - loss: 0.3310 - val_accuracy: 0.8000 - val_loss: 0.3972
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9009 - loss: 0.3655 - val_accuracy: 0.8667 - val_loss: 0.3844
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9193 - loss: 0.3364 - val_accuracy: 0.9333 - val_loss: 0.3671
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9496 - loss: 0.3281 - val_accuracy: 0.8889 - val_loss: 0.3746
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9289 - loss: 0.3486 - val_accuracy: 0.9333 - val_loss: 0.3559
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9606 - loss: 0.3245 - val_accuracy: 0.8889 - val_loss: 0.3636
# Test Loss: 0.3636
# Test Accuracy: 0.8889

# %% [markdown]
# # Compraison

# %%
import pandas as pd
from itertools import groupby


accuracy_results = {
    'Model': ['Decision Tree', 'Random Forest', 'k-NN', 'CNN'],
    'Accuracy': [accuracyDT, accuracyRF, accuracyKNN, accuracyCNN]
}


accuracy_df = pd.DataFrame(accuracy_results)
accuracy_df = accuracy_df.sort_values(by='Accuracy', ascending=False)
accuracy_df = accuracy_df.reset_index(drop=True)

accuracy_df
# Out:
#            Model  Accuracy
# 0  Decision Tree  0.955556
# 1  Random Forest  0.955556
# 2            CNN  0.888889
# 3           k-NN  0.777778
